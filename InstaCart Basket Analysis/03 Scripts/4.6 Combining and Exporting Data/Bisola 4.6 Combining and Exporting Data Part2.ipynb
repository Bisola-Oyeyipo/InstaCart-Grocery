# %% [markdown]
# ### Part 2

# %% [markdown]
# #### Import Libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### Import the dataset from csv and pickle file

# %%
# create the path
path = r'C:\Users\Lumex\Documents\Achievement_4_Project\InstaCart Basket Analysis'
df_prods = pd.read_csv(os.path.join(path, '02 Data' , 'Prepared Data' , 'products_checked.csv'), index_col = False)
orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data' , 'Prepared Data' , 'orders_products_combined.pkl'))

# %%
# check the size of the imported dataframe
orders_products_combined.shape
# Out:
# (32434489, 11)

# %% [markdown]
# ### Understanding the Dataframes that would be Merged

# %%
# Check dataframe structure
orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
# Check the size of df_prods
df_prods.shape
# Out:
# (49672, 6)

# %%
# Check dataframe structure
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# ### Merging

# %% [markdown]
# ##### Observation: The key column between df_prods and orders_product_combined dataframe is the product_id, which is means a merge is possible for both dataframe. i will be using the inner join to merge the dataframes.

# %%
# Merge the df_prods and orders_products_combined
ords_prods_merge = orders_products_combined.merge(df_prods , on = ['product_id'] , indicator = 'match')

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge                             product_name  aisle_id  \
# ...

# %%
# drop the flag column '_merge' from the previous merge
ords_prods_merge.drop('_merge', axis = 1 )
# Out:
#           Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0                    0   2539329        1             1                   2
# 1                    0   2539329        1             1                   2
# 2                    0   2539329        1             1                   2
# 3                    0   2539329        1             1                   2
# 4                    0   2539329        1             1                   2
# ...                ...       ...      ...           ...                 ...
# 32404854       3421081   2977660   206209            13                   1
# 32404855       3421081   2977660   206209            13                   1
# 32404856       3421081   2977660   206209            13                   1
# 32404857       3421081   2977660   206209            13                   1
# 32404858       3421081   2977660   206209            13                   1
#
# ...

# %%
#the value count on _merge column
ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# export the data as pickle
ords_prods_merge.to_pickle(os.path.join(path, '02 Data' , 'Prepared Data' , 'ords_prods_merge.pkl'))

# %% [markdown]
# ##### Observation about the Merged Dataframe: There is a column 'Unnamed' that i would like to understand the values in that column and also the column 'Unnamed_0y' values looks much like the values in the product_id but some of the values are like a number differences which make it intriging on why it is so.
